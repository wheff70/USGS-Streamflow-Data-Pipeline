# %% [markdown]
# # USGS Streamflow API Testing

# %%
import requests

url = "https://api.waterdata.usgs.gov/ogcapi/v0/collections/monitoring-locations/items?f=json&lang=en-US&limit=10&skipGeometry=false&offset=0&state_code=24"
response = requests.get(url).json()
response
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'district_code': '24',
#     'site_type_code': 'SP',
#     'vertical_datum': 'NGVD29',
#     'original_horizontal_datum_name': 'North American Datum of 1983',
#     'well_constructed_depth': None,
#     'monitoring_location_number': '393451077375601',
#     'country_code': 'US',
#     'site_type': 'Spring',
#     'vertical_datum_name': 'National Geodetic Vertical Datum of 1929',
#     'drainage_area': None,
#     'hole_constructed_depth': None,
#     'monitoring_location_name': 'WA Cj 148',
#     'country_name': 'United States of America',
#     'hydrologic_unit_code': '020700041007',
#     'horizontal_positional_accuracy_code': 'S',
#     'contributing_drainage_area': None,
#     'depth_source_code': None,
#     'state_code': '24',
#     'basin_code': None,
#     'horizontal_positional_accuracy': 'Accurate to + or - 1 sec.',
#     'time_zone_abbreviation': 'EST',
#     'state_name': 'Maryland',
# ...
